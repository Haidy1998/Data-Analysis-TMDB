# %% [markdown]
# <a href="https://colab.research.google.com/github/Haidy1998/Data-Analysis-TMDB/blob/main/tmdb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Project: Investigate a Dataset - [TMDB Movie Data]
# Table of Contents
# Introduction
# Data Wrangling
# Exploratory Data Analysis
# Conclusions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %%
tmdb_df = pd.read_csv('tmdb_5000_movies.csv')

# %%
tmdb_df.head(25)
# Out:
#        budget                                             genres  \
# 0   237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1   300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2   245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3   250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4   260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5   258000000  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6   260000000  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7   280000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8   250000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9   250000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10  270000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11  200000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  200000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# ...

# %%
tmdb_df.shape
# Out:
# (4803, 20)

# %%
tmdb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 20 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   budget                4803 non-null   int64
#  1   genres                4803 non-null   object
#  2   homepage              1712 non-null   object
#  3   id                    4803 non-null   int64
#  4   keywords              4803 non-null   object
#  5   original_language     4803 non-null   object
#  6   original_title        4803 non-null   object
#  7   overview              4800 non-null   object
#  8   popularity            4803 non-null   float64
#  9   production_companies  4803 non-null   object
#  10  production_countries  4803 non-null   object
#  11  release_date          4802 non-null   object
#  12  revenue               4803 non-null   int64
#  13  runtime               4801 non-null   float64
#  14  spoken_languages      4803 non-null   object
# ...

# %%
tmdb_df.describe
# Out:
# <bound method NDFrame.describe of          budget                                             genres  \
# 0     237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1     300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2     245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3     250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4     260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...         ...                                                ...
# 4798     220000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4799       9000  [{"id": 35, "name": "Comedy"}, {"id": 10749, "...
# 4800          0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 4801          0                                                 []
# 4802          0                [{"id": 99, "name": "Documentary"}]
#
#                                                homepage      id  \
# ...

# %% [markdown]
# ### Data Cleaning

# %%
tmdb_df.drop(['homepage','id','keywords', 'original_language', 'overview', 'spoken_languages',
              'tagline', 'production_countries'], axis=1, inplace = True)

# %%
tmdb_df.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                              original_title  popularity  \
# 0                                    Avatar  150.437577
# 1  Pirates of the Caribbean: At World's End  139.082615
# 2                                   Spectre  107.376788
#
#                                 production_companies release_date     revenue  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10  2787965087
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...   2007-05-19   961000000
# 2  [{"name": "Columbia Pictures", "id": 5}, {"nam...   2015-10-26   880674609
#
#    runtime    status                                     title  vote_average  \
# 0    162.0  Released                                    Avatar           7.2
# ...

# %%
tmdb_df.isnull().sum()
# Out:
# budget                  0
# genres                  0
# original_title          0
# popularity              0
# production_companies    0
# release_date            1
# revenue                 0
# runtime                 2
# status                  0
# title                   0
# vote_average            0
# vote_count              0
# dtype: int64

# %%
tmdb_df.dropna(inplace= True)

# %%
tmdb_df.isnull().sum().any()
# Out:
# False

# %%
tmdb_df.duplicated().sum()
# Out:
# 0

# %%
tmdb_df.drop_duplicates(inplace= True)

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
# # Question 1
#  what did the most film make revenue?
# #Question 2
#  what is the revenue of the film that make the highest vote_count?
# # Question 3
# what is the most popular genrus ?
# # Question 4
# what is the film of the maximum and minimum vote average ?
# # Question 5
#  what is the revenue of the most popular movie ?

# %%
# Question 1
# what did the most film make revenue? 
tmdb_df.revenue.max()
# Out:
# 2787965087

# %%
tmdb_df.query('revenue == 2787965087')
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#   original_title  popularity  \
# 0         Avatar  150.437577
#
#                                 production_companies release_date     revenue  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...   2009-12-10  2787965087
#
#    runtime    status   title  vote_average  vote_count
# 0    162.0  Released  Avatar           7.2       11800

# %%
# Question 2
# what is the revenue of the film that make the highest vote_count?
tmdb_df.vote_count.max()
# Out:
# 13752

# %%
tmdb_df.query('vote_count == 13752')
# Out:
#        budget                                             genres  \
# 96  160000000  [{"id": 28, "name": "Action"}, {"id": 53, "nam...
#
#    original_title  popularity  \
# 96      Inception   167.58371
#
#                                  production_companies release_date    revenue  \
# 96  [{"name": "Legendary Pictures", "id": 923}, {"...   2010-07-14  825532764
#
#     runtime    status      title  vote_average  vote_count
# 96    148.0  Released  Inception           8.1       13752

# %%
# Question 3
# what is the most popular genrus ?
tmdb_df.genres.nunique()
# Out:
# 1175

# %%
from numpy.core.numeric import indices
genres_classes = ['Action', 'Adventure', 'Fantasy', 'Animation', 'Drama', 'Science Fiction', 'Horror' ]
counts = tmdb_df.groupby(gen[1]).popularity.mean()
indices = np.arange(len(genres_classes))
#plt.bar(indices, genres_classes, alpha = .5)
counts.plot(kind= 'bar', title= 'popularity by genres',alpha=.7)
plt.xlabel('genres', size=18)
plt.ylabel('popularity', size= 18)
# Out:
# Text(0, 0.5, 'popularity')

# %%
gen = tmdb_df['genres'].str.split(',',  expand = True)

# %%
acidity_level = tmdb_df.groupby(gen[1]).popularity.mean()
acidity_level
# Out:
# 1
#  "name": "Action"}              28.635155
#  "name": "Action"}]             23.177815
#  "name": "Adventure"}           40.039761
#  "name": "Adventure"}]          14.427488
#  "name": "Animation"}           35.656554
#  "name": "Animation"}]          17.396752
#  "name": "Comedy"}              14.091627
#  "name": "Comedy"}]             16.873321
#  "name": "Crime"}               19.967102
#  "name": "Crime"}]               1.759506
#  "name": "Documentary"}          5.870410
#  "name": "Documentary"}]         2.830153
#  "name": "Drama"}               17.126245
#  "name": "Drama"}]              13.759799
#  "name": "Family"}              41.185166
#  "name": "Family"}]              0.883343
#  "name": "Fantasy"}             34.126628
#  "name": "Fantasy"}]            28.182213
#  "name": "Foreign"}              0.074425
#  "name": "History"}             19.405199
#  "name": "History"}]            10.144900
#  "name": "Horror"}              19.933242
# ...

# %%
# Question 4 
# what is the film of the maximum and minimum vote average ?
tmdb_df.vote_average.max()
# Out:
# 10.0

# %%
tmdb_df.vote_average.min()
# Out:
# 0.0

# %%
tmdb_df.query('vote_average == 0')
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                          original_title  popularity  \
# 1464                Black Water Transit    0.126738
# 3669               Should've Been Romeo    0.407030
# ...

# %%
# Question 5
# what is the revenue of the most popular movie ?
tmdb_df.popularity.max()
# Out:
# 875.581305

# %%
tmdb_df.query('popularity == 875.581305')
# Out:
#        budget                                             genres  \
# 546  74000000  [{"id": 10751, "name": "Family"}, {"id": 16, "...
#
#     original_title  popularity  \
# 546        Minions  875.581305
#
#                                   production_companies release_date  \
# 546  [{"name": "Universal Pictures", "id": 33}, {"n...   2015-06-17
#
#         revenue  runtime    status    title  vote_average  vote_count
# 546  1156730962     91.0  Released  Minions           6.4        4571

# %%
tmdb_df.release_date = pd.to_datetime(tmdb_df['release_date'])
#tmdb_df.query('release_date > 2014')
tmdb_df.release_date.min()
# Out:
# Timestamp('1916-09-04 00:00:00')

# %%
tmdb_df.release_date.max()
# Out:
# Timestamp('2017-02-03 00:00:00')

# %%
tmdb_df.budget.max()
# Out:
# 380000000

# %%
tmdb_df.query('budget == 380000000')
# Out:
#        budget                                             genres  \
# 17  380000000  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
#
#                                              homepage    id  \
# 17  http://disney.go.com/pirates/index-on-stranger...  1865
#
#                                              keywords original_language  \
# 17  [{"id": 658, "name": "sea"}, {"id": 1316, "nam...                en
#
#                                  original_title  \
# 17  Pirates of the Caribbean: On Stranger Tides
#
#                                              overview  popularity  \
# 17  Captain Jack Sparrow crosses paths with a woma...  135.413856
#
#                                  production_companies  \
# 17  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                  production_countries release_date  \
# 17  [{"iso_3166_1": "US", "name": "United States o...   2011-05-14
#
# ...

# %%
new = tmdb_df.query('release_date < 2000 ')
new.vote_count.max()
tmdb_df.query('vote_count == 9413')
# Out:
#        budget                         genres original_title  popularity  \
# 662  63000000  [{"id": 18, "name": "Drama"}]     Fight Club  146.757391
#
#                                   production_companies release_date  \
# 662  [{"name": "Regency Enterprises", "id": 508}, {...   1999-10-15
#
#        revenue  runtime    status       title  vote_average  vote_count
# 662  100853753    139.0  Released  Fight Club           8.3        9413

# %%
 average_popularity =tmdb_df['popularity'].mean()
# Out:
# 21.49230058817409

# %%
tmdb_df.query('release_date > 2000 ').count()
# Out:
# budget                  3491
# genres                  3491
# original_title          3491
# popularity              3491
# production_companies    3491
# release_date            3491
# revenue                 3491
# runtime                 3491
# status                  3491
# title                   3491
# vote_average            3491
# vote_count              3491
# dtype: int64

# %%
tmdb_df.query('release_date < 2000').count()
# Out:
# budget                  1308
# genres                  1308
# original_title          1308
# popularity              1308
# production_companies    1308
# release_date            1308
# revenue                 1308
# runtime                 1308
# status                  1308
# title                   1308
# vote_average            1308
# vote_count              1308
# dtype: int64

# %%
tmdb_df.vote_count.unique()
# Out:
# array([11800,  4500,  4466, ...,   587,  1708,  2078])

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# 1-The most film made revenues is Avatar from 1916 till 2017.
# 2- The highest budget of a film is 380000000 (Pirates of the Caribbean: On Stranger Tides)
# 3- The film that has the highest vote counts is Inception on 2010 (13752 vote)
# 4- On the nineties, the most film has vote counts is Fight Club	with revenues 100853753.
